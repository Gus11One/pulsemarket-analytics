# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
DATA_STAGING = "../data/staging"

orders = pd.read_csv(f"{DATA_STAGING}/orders_validated.csv")
order_items = pd.read_csv(f"{DATA_STAGING}/order_items_validated.csv")
sellers = pd.read_csv(f"{DATA_STAGING}/sellers_validated.csv")

# %%
orders.head()
order_items.head()
sellers.head()
# Out:
#    order_id  order_date  customer_id order_status channel  valid_status  \
# 0         1  2023-06-29          103    COMPLETED  Mobile          True
# 1         2  2022-01-24          180    completed     web          True
# 2         3  2023-12-19           93     refunded  Mobile         False
# 3         4  2024-01-21           15     canceled     WEB         False
# 4         5  2022-11-20          107     canceled  mobile         False
#
#    valid_order_date
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
#    order_id  product_id  seller_id  quantity  unit_price  valida_quantity  \
# 0       189         199         34        -1           0            False
# 1       487         140          8        10          50             True
# 2       192         137         21        -1          20            False
# 3       447         133         34         3          10             True
# ...

# %%
orders[["valid_status", "valid_order_date"]].mean()
order_items[["valida_quantity", "validate_price"]].mean()
# Out:
# valid_status        0.534
# valid_order_date    1.000
# dtype: float64
# valida_quantity    0.7300
# validate_price     0.6425
# dtype: float64

# %%
sellers["valid_comission"].value_counts(normalize=True)
# Out:
# valid_comission
# False    0.6
# True     0.4
# Name: proportion, dtype: float64
